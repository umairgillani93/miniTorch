# %%
import torch
import torch.nn as nn 

x = torch.randn(10,5,10)

ln = nn.LayerNorm(10)

output = ln(x)

print(output)
# Out:
# tensor([[[ 0.3074, -1.1708,  1.1425, -1.5188, -0.1612,  0.8831, -1.2972,
#            1.2345,  0.8993, -0.3187],
#          [-0.8104,  1.0798,  1.2926,  1.0534, -0.2659, -1.6976, -1.3164,
#           -0.2502,  0.1180,  0.7966],
#          [ 2.1852, -0.2267, -0.5244,  0.6490, -0.7487,  0.5600, -0.2973,
#           -0.7385, -1.5696,  0.7111],
#          [-0.6145, -0.3734, -1.4882,  0.0146,  0.8921, -0.5147,  1.5592,
#           -0.6628,  1.7409, -0.5532],
#          [-0.4692,  0.8950, -0.1143,  0.2332,  1.9557,  0.9413, -1.4721,
#           -0.6527, -0.0500, -1.2669]],
#
#         [[ 1.3518, -0.2457, -1.2948,  0.0465, -0.0446, -1.2476,  2.1218,
#            0.1065, -0.2446, -0.5494],
#          [-0.4371,  0.6222, -0.2351,  0.8365,  0.7787, -1.2042,  0.7668,
#           -0.7636, -1.8211,  1.4568],
#          [ 0.5782,  1.9867,  0.5154,  0.6565, -1.7894, -0.6073,  0.2540,
#           -1.1273, -0.1746, -0.2920],
#          [-1.0842,  1.3829,  1.3543,  0.0477, -1.7598, -0.7746,  0.8796,
# ...
